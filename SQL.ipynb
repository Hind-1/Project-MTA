# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pandas as pd

# %%
def get_data(nums):
    dfs=[]
    URL='http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt'
    for i in nums:    
        URLs=URL.format(i)
        dfs.append(pd.read_csv(URLs))        
    return pd.concat(dfs)
nums=[160903,160910,160917]
get_data(nums)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 192873  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192874  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192875  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192876  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192877  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
NYPD_Complaint_Data=pd.read_csv('https://data.cityofnewyork.us/api/views/5uac-w243/rows.csv?accessType=DOWNLOAD')
NYPD_Complaint_Data
# Out:
#         CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0        758521794           67            NaN   03/07/2021     01:50:00
# 1        696896951           60            NaN   03/26/2021     18:40:00
# 2        972479923           75       BROOKLYN   03/27/2021     15:55:00
# 3        109344500           77       BROOKLYN   03/28/2021     11:10:00
# 4        673945415           23            NaN   03/29/2021     23:13:00
# ...            ...          ...            ...          ...          ...
# 204641   154508455          121  STATEN ISLAND   04/03/2021     01:34:00
# 204642   392278526          104         QUEENS   04/01/2021     23:00:00
# 204643   730121906           34      MANHATTAN   03/20/2021     16:00:00
# 204644   788230671           75       BROOKLYN   04/04/2021     04:10:00
# 204645   906755938            7      MANHATTAN   03/27/2021     21:00:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# ...

# %% [markdown]
# SQLalchemy

# %%
engine = create_engine("sqlite:///Users/hindsalem/data_base.db")

# %%
all_tables = engine.table_names()
all_tables
# Out:
# <ipython-input-9-94603f164bb3>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   all_tables = engine.table_names()
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# ...

# %%
doctors_data = pd.read_sql('SELECT * FROM NYPD;', engine)
doctors_data
